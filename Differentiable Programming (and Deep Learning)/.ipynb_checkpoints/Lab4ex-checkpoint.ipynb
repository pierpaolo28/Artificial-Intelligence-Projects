# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Wide-MLPs-on-MNIST" data-toc-modified-id="Wide-MLPs-on-MNIST-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Wide MLPs on MNIST</a></span></li></ul></div>

# %% [markdown]
# # Lab 4 Exercise - Fun with MLPs & MNIST

# %% [markdown]
# In the lab exercise you built a BaselineModel which was a simple MLP with one hidden layer and trained
# it on MNIST. You’re now going to explore this model further.

# %%
import torch
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch import nn
from torch import optim
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from ipywidgets import *
import warnings
warnings.filterwarnings('ignore')
sns.set()

# %% [markdown]
# ## Wide MLPs on MNIST

# %% [markdown]
# Consider an MLP with a single hidden layer. How wide does the network need to be (how many hidden
# units) before it overfitsa on the MNIST training dataset? Provide rationale (1 mark) and experimental
# evidence for your findings (see below), and suggest reasons why they might be so (1 mark).
# For practical purposes you’re limited by available GPU memory; don’t try training networks with more
# than 500,000 hidden units, which have almost 400 million learnable parameters! For experimental evidence you should include training curves (plots of loss and accuracy against epochs) with both the
# training and test data for a range of different sized models (3 marks).

# %%
# fix random seed for reproducibility
seed = 7
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)

# %%
# flatten 28*28 images to a 784 vector for each image
transform = transforms.Compose([
    transforms.ToTensor(),  # convert to tensor
    transforms.Lambda(lambda x: x.view(-1))  # flatten into vector
])

# %%
trainset = MNIST(".", train=True, download=True, transform=transform)
testset = MNIST(".", train=False, download=True, transform=transform)

# %%
# create data loaders
trainloader = DataLoader(trainset, batch_size=128, shuffle=True)
testloader = DataLoader(testset, batch_size=128, shuffle=True)

# %%
# define baseline model
class BaselineModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(BaselineModel, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size).cuda()
        self.fc2 = nn.Linear(hidden_size, num_classes).cuda()  
    
    def forward(self, x):
        out = self.fc1(x)
        out = F.relu(out)
        out = self.fc2(out)
        # if not self.training:
        #    out = F.softmax(out, dim=1)
        return out

# %%
def train_model(model, criterion, optimizer, num_epochs=5):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    loss_plot, acc_plot = [], []
    val_loss_plot, val_acc_plot = [], []
    for epoch in range(num_epochs):
        # print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        # print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    # Next two lines enable us to use Binary Crossentropy
                    #outputs = outputs.squeeze(1)
                    #loss = criterion(outputs, labels)
                    loss = criterion(outputs, labels.long())

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data.long())

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            if phase == 'train':
                loss_plot.append(epoch_loss)
                acc_plot.append(epoch_acc)
            else:
                val_loss_plot.append(epoch_loss)
                val_acc_plot.append(epoch_acc)

            # print('{} Loss: {:.4f} Acc: {:.4f}'.format(
            #     phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

        # print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    print('Best val Loss: {:4f}'.format(best_loss))

    # loading best model weights
    model.load_state_dict(best_model_wts)
    train_val_plot(loss_plot, val_loss_plot, acc_plot, val_acc_plot)
    return model

# %%
def train_val_plot(loss_plot, val_loss_plot, acc_plot, val_acc_plot):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
    #plt.tight_layout()
    ax[0].plot(loss_plot, label="Training Loss")
    ax[0].plot(val_loss_plot, label="Test Loss")
    ax[0].legend(fontsize=18)
    ax[0].grid(True)
    ax[0].set_title("Training/Test Loss", fontsize=20);
    ax[0].set_xlabel("Epoch", fontsize=18);
    ax[0].set_ylabel("Loss", fontsize=18);
    ax[1].plot(acc_plot, label="Training accuracy")
    ax[1].plot(val_acc_plot, label="Test accuracy")
    ax[1].legend(fontsize=18)
    ax[1].grid(True)
    ax[1].set_title("Training/Test Accuracy", fontsize=20);
    ax[1].set_xlabel("Epoch", fontsize=18);
    ax[1].set_ylabel("Accuracy (%)", fontsize=18);
    plt.savefig("Training.png", format='png', dpi=1200)
    plt.show()

# %%
import time
import copy

dataloaders = {'train': trainloader, 'val': testloader}
dataset_sizes = {'train': len(trainloader.dataset), 'val': len(testloader.dataset)}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
for i in range(5, 500, 50):
      model = BaselineModel(784, i, 10)
      print(model)
      criterion = nn.CrossEntropyLoss()
      optimizer_ft = optim.Adam(model.parameters())
      train_model(model, criterion, optimizer_ft, num_epochs=10)
# Out:
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# )
# Training complete in 0m 51s
# Best val Acc: 0.884100
# Best val Loss: 0.404776
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=55, bias=True)
#   (fc2): Linear(in_features=55, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.972600
# Best val Loss: 0.093787
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=105, bias=True)
#   (fc2): Linear(in_features=105, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.976300
# Best val Loss: 0.081033
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=155, bias=True)
#   (fc2): Linear(in_features=155, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.979400
# Best val Loss: 0.072404
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=205, bias=True)
#   (fc2): Linear(in_features=205, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.978600
# Best val Loss: 0.071301
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=255, bias=True)
#   (fc2): Linear(in_features=255, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.978900
# Best val Loss: 0.070510
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=305, bias=True)
#   (fc2): Linear(in_features=305, out_features=10, bias=True)
# )
# Training complete in 0m 51s
# Best val Acc: 0.980800
# Best val Loss: 0.063321
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=355, bias=True)
#   (fc2): Linear(in_features=355, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.981200
# Best val Loss: 0.064537
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=405, bias=True)
#   (fc2): Linear(in_features=405, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.981000
# Best val Loss: 0.062793
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=455, bias=True)
#   (fc2): Linear(in_features=455, out_features=10, bias=True)
# )
# Training complete in 0m 51s
# Best val Acc: 0.981000
# Best val Loss: 0.068076

# %%
model = BaselineModel(784, 800, 10)
print(model)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model.parameters())
train_model(model, criterion, optimizer_ft, num_epochs=10)
# Out:
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=800, bias=True)
#   (fc2): Linear(in_features=800, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.982000
# Best val Loss: 0.064182
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=800, bias=True)
#   (fc2): Linear(in_features=800, out_features=10, bias=True)
# )

# %%
model = BaselineModel(784, 200000, 10)
print(model)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model.parameters())
train_model(model, criterion, optimizer_ft, num_epochs=10)
# Out:
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=200000, bias=True)
#   (fc2): Linear(in_features=200000, out_features=10, bias=True)
# )
# Training complete in 4m 22s
# Best val Acc: 0.982900
# Best val Loss: 0.080694
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=200000, bias=True)
#   (fc2): Linear(in_features=200000, out_features=10, bias=True)
# )

# %%
for i in range(3, 50, 3):
      model = BaselineModel(784, i, 10)
      print(model)
      criterion = nn.CrossEntropyLoss()
      optimizer_ft = optim.Adam(model.parameters())
      train_model(model, criterion, optimizer_ft, num_epochs=10)
# Out:
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=3, bias=True)
#   (fc2): Linear(in_features=3, out_features=10, bias=True)
# )
# Training complete in 0m 54s
# Best val Acc: 0.770100
# Best val Loss: 0.705550
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=6, bias=True)
#   (fc2): Linear(in_features=6, out_features=10, bias=True)
# )
# Training complete in 0m 54s
# Best val Acc: 0.906900
# Best val Loss: 0.327605
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=9, bias=True)
#   (fc2): Linear(in_features=9, out_features=10, bias=True)
# )
# Training complete in 0m 54s
# Best val Acc: 0.925100
# Best val Loss: 0.266906
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=12, bias=True)
#   (fc2): Linear(in_features=12, out_features=10, bias=True)
# )
# Training complete in 0m 54s
# Best val Acc: 0.934700
# Best val Loss: 0.223320
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=15, bias=True)
#   (fc2): Linear(in_features=15, out_features=10, bias=True)
# )
# Training complete in 0m 53s
# Best val Acc: 0.939600
# Best val Loss: 0.210712
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=18, bias=True)
#   (fc2): Linear(in_features=18, out_features=10, bias=True)
# )
# Training complete in 0m 53s
# Best val Acc: 0.946000
# Best val Loss: 0.187663
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=21, bias=True)
#   (fc2): Linear(in_features=21, out_features=10, bias=True)
# )
# Training complete in 0m 53s
# Best val Acc: 0.949600
# Best val Loss: 0.174462
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=24, bias=True)
#   (fc2): Linear(in_features=24, out_features=10, bias=True)
# )
# Training complete in 0m 53s
# Best val Acc: 0.958200
# Best val Loss: 0.140780
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=27, bias=True)
#   (fc2): Linear(in_features=27, out_features=10, bias=True)
# )
# Training complete in 0m 53s
# Best val Acc: 0.957800
# Best val Loss: 0.142927
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=30, bias=True)
#   (fc2): Linear(in_features=30, out_features=10, bias=True)
# )
# Training complete in 0m 53s
# Best val Acc: 0.961600
# Best val Loss: 0.132942
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=33, bias=True)
#   (fc2): Linear(in_features=33, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.962300
# Best val Loss: 0.133518
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=36, bias=True)
#   (fc2): Linear(in_features=36, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.960700
# Best val Loss: 0.132643
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=39, bias=True)
#   (fc2): Linear(in_features=39, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.963900
# Best val Loss: 0.118759
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=42, bias=True)
#   (fc2): Linear(in_features=42, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.968400
# Best val Loss: 0.107704
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=45, bias=True)
#   (fc2): Linear(in_features=45, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.965400
# Best val Loss: 0.116414
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=48, bias=True)
#   (fc2): Linear(in_features=48, out_features=10, bias=True)
# )
# Training complete in 0m 52s
# Best val Acc: 0.969000
# Best val Loss: 0.108254

# %%
def test_model(model, testloader):
    model.eval()
    # Computing the model accuracy on the test set
    correct, total = 0, 0
    for x, y in testloader:
        outputs = model(x.cuda())
        winners = outputs.argmax(dim=1)
        count = [1 for i, j in zip(winners, y.cuda().long()) if i == j]
        correct += sum(count)
        total += len(y)
    print('Test Accuracy: %2.2f %%' % ((100.0 * correct) / total))
    
test_model(model, testloader)
# Out:
# Test Accuracy: 98.02 %

# %%
def confusion_matrix(data, nb_classes):
    df_cm = pd.DataFrame(data, 
                          range(nb_classes), range(nb_classes))
    plt.figure(figsize=(10,7))
    sns.set(font_scale=1.4) # for label size
    sns.heatmap(df_cm, annot=True, annot_kws={"size": 16},cmap='Blues', 
                fmt='g')
    plt.title("Confusion Matrix", fontsize = 20)
    plt.xlabel("Predicted Output", fontsize = 18)
    plt.ylabel("Expected Output", fontsize = 18)
    #plt.savefig("confusion_matrix.png", format='png', dpi=1200)
    plt.show()

# ! pip install PTable
# from prettytable import PrettyTable
def summary_table(data, nb_classes):
    p = PrettyTable(data)
    p.title = 'Predicted Output'
    for head, row in zip([i for i in range(0, nb_classes)], data):
        r = [head]
        r.extend(row)
        p.add_row(r)
    l = ['    ']
    l.extend([i for i in range(0, nb_classes)])
    p.field_names = l
    print(p)

# %%
def acc_per_class(model, testloader, nb_classes):
      model.eval()
      confusion_mat = torch.zeros(nb_classes, nb_classes)
      class_correct = torch.zeros(10)
      class_total = torch.zeros(10)
      total = 0
      for inputs, labels in testloader:
          outputs = model(inputs.cuda())
          _, preds = torch.max(outputs, 1)
          for t, p in zip(labels.view(-1), preds.view(-1)):
                  confusion_mat[t.long(), p.long()] += 1

      confusion_matrix(confusion_mat.data.cpu().numpy(), nb_classes)

      per_class_acc = 100*confusion_mat.diag()/confusion_mat.sum(1)
      for i, j in enumerate(per_class_acc.data.cpu().numpy()):
        print("Class:", i, "Accuracy:", j)
      acc = torch.mean(per_class_acc).data.cpu().numpy()
      print("Overall Accuracy: ", acc, "%")

acc_per_class(model, testloader, 10)
# Out:
# Class: 0 Accuracy: 98.97959
# Class: 1 Accuracy: 98.94273
# Class: 2 Accuracy: 97.77132
# Class: 3 Accuracy: 97.821785
# Class: 4 Accuracy: 96.84318
# Class: 5 Accuracy: 97.19731
# Class: 6 Accuracy: 97.59917
# Class: 7 Accuracy: 98.44358
# Class: 8 Accuracy: 97.74127
# Class: 9 Accuracy: 98.61249
# Overall Accuracy:  97.99525 %

# %%
def train_model_hidden(model, criterion, optimizer, num_epochs=5):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    loss_plot, acc_plot = [], []
    val_loss_plot, val_acc_plot = [], []
    for epoch in range(num_epochs):
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels.long())

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data.long())

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            if phase == 'train':
                loss_plot.append(epoch_loss)
                acc_plot.append(epoch_acc)
            else:
                val_loss_plot.append(epoch_loss)
                val_acc_plot.append(epoch_acc)
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    print('Best val Loss: {:4f}'.format(best_loss))

    # loading best model weights
    model.load_state_dict(best_model_wts)
    #train_val_plot(loss_plot, val_loss_plot, acc_plot, val_acc_plot)
    return model, loss_plot, val_loss_plot, acc_plot, val_acc_plot

# %%
import time
import copy

dataloaders = {'train': trainloader, 'val': testloader}
dataset_sizes = {'train': len(trainloader.dataset), 'val': len(testloader.dataset)}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
t_l, v_l, t_a, v_a = [], [], [], []
for i in range(5, 1000, 100):
      model = BaselineModel(784, i, 10)
      print(model)
      criterion = nn.CrossEntropyLoss()
      optimizer_ft = optim.Adam(model.parameters())
      _, loss_plot, val_loss_plot, acc_plot, val_acc_plot = train_model_hidden(model, criterion, optimizer_ft, num_epochs=10)
      t_l.append(loss_plot[len(loss_plot)-1])
      v_l.append(val_loss_plot[len(val_loss_plot)-1])
      t_a.append(acc_plot[len(acc_plot)-1])
      v_a.append(val_acc_plot[len(val_acc_plot)-1])
# Out:
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.863100
# Best val Loss: 0.482125
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=105, bias=True)
#   (fc2): Linear(in_features=105, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.975700
# Best val Loss: 0.078764
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=205, bias=True)
#   (fc2): Linear(in_features=205, out_features=10, bias=True)
# )
# Training complete in 0m 60s
# Best val Acc: 0.979300
# Best val Loss: 0.070709
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=305, bias=True)
#   (fc2): Linear(in_features=305, out_features=10, bias=True)
# )
# Training complete in 0m 60s
# Best val Acc: 0.981500
# Best val Loss: 0.060351
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=405, bias=True)
#   (fc2): Linear(in_features=405, out_features=10, bias=True)
# )
# Training complete in 0m 60s
# Best val Acc: 0.980900
# Best val Loss: 0.061488
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=505, bias=True)
#   (fc2): Linear(in_features=505, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.980400
# Best val Loss: 0.065844
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=605, bias=True)
#   (fc2): Linear(in_features=605, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.982200
# Best val Loss: 0.056672
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=705, bias=True)
#   (fc2): Linear(in_features=705, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.981400
# Best val Loss: 0.061887
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=805, bias=True)
#   (fc2): Linear(in_features=805, out_features=10, bias=True)
# )
# Training complete in 0m 60s
# Best val Acc: 0.980700
# Best val Loss: 0.062470
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=905, bias=True)
#   (fc2): Linear(in_features=905, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.981800
# Best val Loss: 0.064722

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
# plt.tight_layout()
l = [i for i in range(5, 1000, 100)]
ax[0].plot(l, t_l, label="Training Loss")
ax[0].plot(l, v_l, label="Test Loss")
ax[0].legend(fontsize=18)
ax[0].grid(True)
ax[0].set_title("Training/Test Loss vs N. of Hidden Units", fontsize=20);
ax[0].set_xlabel("N. of Hidden Units", fontsize=18);
ax[0].set_ylabel("Loss", fontsize=18);
ax[1].plot(l, t_a, label="Training accuracy")
ax[1].plot(l, v_a, label="Test accuracy")
ax[1].legend(fontsize=18)
ax[1].grid(True)
ax[1].set_title("Training/Test Accuracy vs N. of Hidden Units", fontsize=20);
ax[1].set_xlabel("N. of Hidden Units", fontsize=18);
ax[1].set_ylabel("Accuracy (%)", fontsize=18);
plt.savefig("Hidden_Units.png", format='png', dpi=1200)
plt.show()

# %%
import time
import copy

dataloaders = {'train': trainloader, 'val': testloader}
dataset_sizes = {'train': len(trainloader.dataset), 'val': len(testloader.dataset)}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
t_l, v_l, t_a, v_a = [], [], [], []
for i in range(1, 200, 5):
      model = BaselineModel(784, i, 10)
      print(model)
      criterion = nn.CrossEntropyLoss()
      optimizer_ft = optim.Adam(model.parameters())
      _, loss_plot, val_loss_plot, acc_plot, val_acc_plot = train_model_hidden(model, criterion, optimizer_ft, num_epochs=10)
      t_l.append(loss_plot[len(loss_plot)-1])
      v_l.append(val_loss_plot[len(val_loss_plot)-1])
      t_a.append(acc_plot[len(acc_plot)-1])
      v_a.append(val_acc_plot[len(val_acc_plot)-1])
# Out:
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=1, bias=True)
#   (fc2): Linear(in_features=1, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.296000
# Best val Loss: 1.671847
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=6, bias=True)
#   (fc2): Linear(in_features=6, out_features=10, bias=True)
# )
# Training complete in 0m 57s
# Best val Acc: 0.891200
# Best val Loss: 0.371547
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=11, bias=True)
#   (fc2): Linear(in_features=11, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.931800
# Best val Loss: 0.245371
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.943100
# Best val Loss: 0.199282
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=21, bias=True)
#   (fc2): Linear(in_features=21, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.955000
# Best val Loss: 0.157809
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=26, bias=True)
#   (fc2): Linear(in_features=26, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.958500
# Best val Loss: 0.142469
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=31, bias=True)
#   (fc2): Linear(in_features=31, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.962500
# Best val Loss: 0.132048
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=36, bias=True)
#   (fc2): Linear(in_features=36, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.961600
# Best val Loss: 0.128995
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=41, bias=True)
#   (fc2): Linear(in_features=41, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.966200
# Best val Loss: 0.109160
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=46, bias=True)
#   (fc2): Linear(in_features=46, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.969200
# Best val Loss: 0.103489
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=51, bias=True)
#   (fc2): Linear(in_features=51, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.969600
# Best val Loss: 0.101090
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=56, bias=True)
#   (fc2): Linear(in_features=56, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.970500
# Best val Loss: 0.097808
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=61, bias=True)
#   (fc2): Linear(in_features=61, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.970400
# Best val Loss: 0.099069
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=66, bias=True)
#   (fc2): Linear(in_features=66, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.973300
# Best val Loss: 0.092523
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=71, bias=True)
#   (fc2): Linear(in_features=71, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.972200
# Best val Loss: 0.090110
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=76, bias=True)
#   (fc2): Linear(in_features=76, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.973200
# Best val Loss: 0.091241
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=81, bias=True)
#   (fc2): Linear(in_features=81, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.974300
# Best val Loss: 0.081342
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=86, bias=True)
#   (fc2): Linear(in_features=86, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.974100
# Best val Loss: 0.085933
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=91, bias=True)
#   (fc2): Linear(in_features=91, out_features=10, bias=True)
# )
# Training complete in 1m 2s
# Best val Acc: 0.974900
# Best val Loss: 0.084415
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=96, bias=True)
#   (fc2): Linear(in_features=96, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.975000
# Best val Loss: 0.084771
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=101, bias=True)
#   (fc2): Linear(in_features=101, out_features=10, bias=True)
# )
# Training complete in 0m 60s
# Best val Acc: 0.974700
# Best val Loss: 0.086714
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=106, bias=True)
#   (fc2): Linear(in_features=106, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.977100
# Best val Loss: 0.080342
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=111, bias=True)
#   (fc2): Linear(in_features=111, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.975900
# Best val Loss: 0.083834
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=116, bias=True)
#   (fc2): Linear(in_features=116, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.976800
# Best val Loss: 0.072409
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=121, bias=True)
#   (fc2): Linear(in_features=121, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.977100
# Best val Loss: 0.076761
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=126, bias=True)
#   (fc2): Linear(in_features=126, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.977900
# Best val Loss: 0.072653
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=131, bias=True)
#   (fc2): Linear(in_features=131, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.975300
# Best val Loss: 0.078858
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=136, bias=True)
#   (fc2): Linear(in_features=136, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.978700
# Best val Loss: 0.074000
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=141, bias=True)
#   (fc2): Linear(in_features=141, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.978600
# Best val Loss: 0.070279
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=146, bias=True)
#   (fc2): Linear(in_features=146, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.977900
# Best val Loss: 0.075832
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=151, bias=True)
#   (fc2): Linear(in_features=151, out_features=10, bias=True)
# )
# Training complete in 0m 59s
# Best val Acc: 0.976400
# Best val Loss: 0.074957
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=156, bias=True)
#   (fc2): Linear(in_features=156, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.977400
# Best val Loss: 0.072937
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=161, bias=True)
#   (fc2): Linear(in_features=161, out_features=10, bias=True)
# )
# Training complete in 0m 60s
# Best val Acc: 0.977600
# Best val Loss: 0.070404
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=166, bias=True)
#   (fc2): Linear(in_features=166, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.980200
# Best val Loss: 0.068874
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=171, bias=True)
#   (fc2): Linear(in_features=171, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.979000
# Best val Loss: 0.066873
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=176, bias=True)
#   (fc2): Linear(in_features=176, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.978200
# Best val Loss: 0.069408
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=181, bias=True)
#   (fc2): Linear(in_features=181, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.978400
# Best val Loss: 0.066620
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=186, bias=True)
#   (fc2): Linear(in_features=186, out_features=10, bias=True)
# )
# Training complete in 0m 60s
# Best val Acc: 0.979600
# Best val Loss: 0.069742
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=191, bias=True)
#   (fc2): Linear(in_features=191, out_features=10, bias=True)
# )
# Training complete in 1m 0s
# Best val Acc: 0.978200
# Best val Loss: 0.073637
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=196, bias=True)
#   (fc2): Linear(in_features=196, out_features=10, bias=True)
# )
# Training complete in 1m 1s
# Best val Acc: 0.979100
# Best val Loss: 0.066911

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
# plt.tight_layout()
l = [i for i in range(1, 200, 5)]
ax[0].plot(l, t_l, label="Training Loss")
ax[0].plot(l, v_l, label="Test Loss")
ax[0].legend(fontsize=18)
ax[0].grid(True)
ax[0].set_title("Training/Test Loss vs N. of Hidden Units", fontsize=20);
ax[0].set_xlabel("N. of Hidden Units", fontsize=18);
ax[0].set_ylabel("Loss", fontsize=18);
ax[1].plot(l, t_a, label="Training accuracy")
ax[1].plot(l, v_a, label="Test accuracy")
ax[1].legend(fontsize=18)
ax[1].grid(True)
ax[1].set_title("Training/Test Accuracy vs N. of Hidden Units", fontsize=20);
ax[1].set_xlabel("N. of Hidden Units", fontsize=18);
ax[1].set_ylabel("Accuracy (%)", fontsize=18);
plt.savefig("Closeup_Hidden_Units.png", format='png', dpi=1200)
plt.show()

# %%
import time
import copy

dataloaders = {'train': trainloader, 'val': testloader}
dataset_sizes = {'train': len(trainloader.dataset), 'val': len(testloader.dataset)}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
t_l, v_l, t_a, v_a = [], [], [], []
for i in range(5, 300000, 50000):
      model = BaselineModel(784, i, 10)
      print(model)
      criterion = nn.CrossEntropyLoss()
      optimizer_ft = optim.Adam(model.parameters())
      _, loss_plot, val_loss_plot, acc_plot, val_acc_plot = train_model_hidden(model, criterion, optimizer_ft, num_epochs=10)
      t_l.append(loss_plot[len(loss_plot)-1])
      v_l.append(val_loss_plot[len(val_loss_plot)-1])
      t_a.append(acc_plot[len(acc_plot)-1])
      v_a.append(val_acc_plot[len(val_acc_plot)-1])
# Out:
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=10, bias=True)
# )
# Training complete in 0m 58s
# Best val Acc: 0.858900
# Best val Loss: 0.478385
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=50005, bias=True)
#   (fc2): Linear(in_features=50005, out_features=10, bias=True)
# )
# Training complete in 2m 30s
# Best val Acc: 0.981500
# Best val Loss: 0.103790
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=100005, bias=True)
#   (fc2): Linear(in_features=100005, out_features=10, bias=True)
# )
# Training complete in 4m 8s
# Best val Acc: 0.980700
# Best val Loss: 0.099154
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=150005, bias=True)
#   (fc2): Linear(in_features=150005, out_features=10, bias=True)
# )
# Training complete in 5m 44s
# Best val Acc: 0.980500
# Best val Loss: 0.083012
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=200005, bias=True)
#   (fc2): Linear(in_features=200005, out_features=10, bias=True)
# )
# Training complete in 7m 21s
# Best val Acc: 0.983400
# Best val Loss: 0.092046
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=250005, bias=True)
#   (fc2): Linear(in_features=250005, out_features=10, bias=True)
# )
# Training complete in 8m 59s
# Best val Acc: 0.981200
# Best val Loss: 0.112038

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
# plt.tight_layout()
l = [i for i in range(5, 300000, 50000)]
ax[0].plot(l, t_l, label="Training Loss")
ax[0].plot(l, v_l, label="Test Loss")
ax[0].legend(fontsize=18)
ax[0].grid(True)
ax[0].set_title("Training/Test Loss vs N. of Hidden Units", fontsize=20);
ax[0].set_xlabel("N. of Hidden Units", fontsize=18);
ax[0].set_ylabel("Loss", fontsize=18);
ax[1].plot(l, t_a, label="Training accuracy")
ax[1].plot(l, v_a, label="Test accuracy")
ax[1].legend(fontsize=18)
ax[1].grid(True)
ax[1].set_title("Training/Test Accuracy vs N. of Hidden Units", fontsize=20);
ax[1].set_xlabel("N. of Hidden Units", fontsize=18);
ax[1].set_ylabel("Accuracy (%)", fontsize=18);
plt.savefig("Full_Hidden_Units.png", format='png', dpi=1200)
plt.show()

# %%
import time
import copy

dataloaders = {'train': trainloader, 'val': testloader}
dataset_sizes = {'train': len(trainloader.dataset), 'val': len(testloader.dataset)}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = BaselineModel(784, 20, 10)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model.parameters())
train_model(model, criterion, optimizer_ft, num_epochs=10)
# Out:
# Training complete in 0m 59s
# Best val Acc: 0.946600
# Best val Loss: 0.182642
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=10, bias=True)
# )

# %%
import time
import copy

dataloaders = {'train': trainloader, 'val': testloader}
dataset_sizes = {'train': len(trainloader.dataset), 'val': len(testloader.dataset)}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = BaselineModel(784, 25000, 10)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(model.parameters())
train_model(model, criterion, optimizer_ft, num_epochs=10)
# Out:
# Training complete in 1m 41s
# Best val Acc: 0.980900
# Best val Loss: 0.096463
# BaselineModel(
#   (fc1): Linear(in_features=784, out_features=25000, bias=True)
#   (fc2): Linear(in_features=25000, out_features=10, bias=True)
# )
