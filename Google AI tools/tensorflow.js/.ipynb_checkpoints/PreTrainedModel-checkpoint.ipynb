# %% [markdown]
# **Pima Indians Diabetes Database**

# %% [markdown]
# In this example, I first load the Pima Indian Dataset and I then train a Multi Layer Perceptron using Tensorflow Eager Execution (executes operations immediately, without building graphs: operations return concrete values instead of constructing a computational graph to run later). Finally I will save the trained model and deploy it dirently online to make predictions.

# %% [markdown]
# **Preprocessing**

# %%
import tensorflowjs as tfjs
import tensorflow as tf
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.utils import np_utils

# %%
print(tensorflow.__version__)
# Out:
# 1.14.0

# %%
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("pima_indian_data.csv")
#df = df.drop('Unnamed: 0', axis=1)
df.head()
# print(df.shape)
# print(df.columns)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#df.to_csv("pima.csv", index=False)

# %% [markdown]
# **Data Visualization**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

corr=df.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %% [markdown]
# **Deep Learning**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = df.drop(['Outcome'], axis = 1).values
Y = df['Outcome']

X = StandardScaler().fit_transform(X)

X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.30, random_state = 101)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Initialize the constructor
model = tf.keras.Sequential([
  tf.keras.layers.Dense(13, activation='relu', input_shape=(8,)),  # must declare input shape
  tf.keras.layers.Dense(60, activation='relu'),
  tf.keras.layers.Dense(30, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(1, activation='relu')
])
# Model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 13)                117
# _________________________________________________________________
# dense_11 (Dense)             (None, 60)                840
# _________________________________________________________________
# dense_12 (Dense)             (None, 30)                1830
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                310
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 3,108
# Trainable params: 3,108
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(X_Train, Y_Train,epochs=100, batch_size=256)
# Out:
# Epoch 1/100
# 537/537 [==============================] - 0s 367us/sample - loss: 0.4249 - acc: 0.7803
# Epoch 2/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.4924 - acc: 0.7914
# Epoch 3/100
# 537/537 [==============================] - 0s 24us/sample - loss: 0.4144 - acc: 0.7933
# Epoch 4/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.4261 - acc: 0.7765
# Epoch 5/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.4325 - acc: 0.7672
# Epoch 6/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.4223 - acc: 0.7747
# Epoch 7/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.4133 - acc: 0.7877
# Epoch 8/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.4120 - acc: 0.7896
# Epoch 9/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.4096 - acc: 0.7877
# Epoch 10/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.4060 - acc: 0.7933
# Epoch 11/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.4040 - acc: 0.7933
# Epoch 12/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.4018 - acc: 0.7970
# Epoch 13/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3994 - acc: 0.8007
# Epoch 14/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3957 - acc: 0.8063
# Epoch 15/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.3939 - acc: 0.8119
# Epoch 16/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3935 - acc: 0.8082
# Epoch 17/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.3891 - acc: 0.8045
# Epoch 18/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3883 - acc: 0.8063
# Epoch 19/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3892 - acc: 0.8007
# Epoch 20/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3880 - acc: 0.8045
# Epoch 21/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3832 - acc: 0.8101
# Epoch 22/100
# 537/537 [==============================] - 0s 24us/sample - loss: 0.3824 - acc: 0.8082
# Epoch 23/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3807 - acc: 0.8138
# Epoch 24/100
# 537/537 [==============================] - 0s 22us/sample - loss: 0.3783 - acc: 0.8138
# Epoch 25/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3751 - acc: 0.8212
# Epoch 26/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3735 - acc: 0.8231
# Epoch 27/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3715 - acc: 0.8231
# Epoch 28/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3700 - acc: 0.8324
# Epoch 29/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3686 - acc: 0.8343
# Epoch 30/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3685 - acc: 0.8287
# Epoch 31/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.3695 - acc: 0.8305
# Epoch 32/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3644 - acc: 0.8324
# Epoch 33/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3597 - acc: 0.8231
# Epoch 34/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3616 - acc: 0.8194
# Epoch 35/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3626 - acc: 0.8287
# Epoch 36/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3582 - acc: 0.8250
# Epoch 37/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3534 - acc: 0.8250
# Epoch 38/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3535 - acc: 0.8250
# Epoch 39/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3537 - acc: 0.8287
# Epoch 40/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3504 - acc: 0.8305
# Epoch 41/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3483 - acc: 0.8250
# Epoch 42/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3516 - acc: 0.8194
# Epoch 43/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3545 - acc: 0.8231
# Epoch 44/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3497 - acc: 0.8287
# Epoch 45/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.3437 - acc: 0.8268
# Epoch 46/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3420 - acc: 0.8305
# Epoch 47/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3396 - acc: 0.8305
# Epoch 48/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3376 - acc: 0.8324
# Epoch 49/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3367 - acc: 0.8343
# Epoch 50/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3370 - acc: 0.8361
# Epoch 51/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3343 - acc: 0.8287
# Epoch 52/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3327 - acc: 0.8343
# Epoch 53/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3342 - acc: 0.8250
# Epoch 54/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3345 - acc: 0.8268
# Epoch 55/100
# 537/537 [==============================] - 0s 22us/sample - loss: 0.3301 - acc: 0.8324
# Epoch 56/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3268 - acc: 0.8380
# Epoch 57/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3256 - acc: 0.8380
# Epoch 58/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.3241 - acc: 0.8399
# Epoch 59/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3225 - acc: 0.8380
# Epoch 60/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3207 - acc: 0.8380
# Epoch 61/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.3259 - acc: 0.8361
# Epoch 62/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.3339 - acc: 0.8380
# Epoch 63/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3232 - acc: 0.8473
# Epoch 64/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.3232 - acc: 0.8361
# Epoch 65/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3254 - acc: 0.8287
# Epoch 66/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3155 - acc: 0.8436
# Epoch 67/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3130 - acc: 0.8454
# Epoch 68/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3138 - acc: 0.8417
# Epoch 69/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.3119 - acc: 0.8436
# Epoch 70/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3093 - acc: 0.8473
# Epoch 71/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3052 - acc: 0.8454
# Epoch 72/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3082 - acc: 0.8399
# Epoch 73/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3086 - acc: 0.8417
# Epoch 74/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3061 - acc: 0.8380
# Epoch 75/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3063 - acc: 0.8305
# Epoch 76/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.3064 - acc: 0.8399
# Epoch 77/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3026 - acc: 0.8454
# Epoch 78/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.2992 - acc: 0.8473
# Epoch 79/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.3039 - acc: 0.8492
# Epoch 80/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.3029 - acc: 0.8473
# Epoch 81/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.2964 - acc: 0.8492
# Epoch 82/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.2954 - acc: 0.8492
# Epoch 83/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.2961 - acc: 0.8547
# Epoch 84/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.2947 - acc: 0.8529
# Epoch 85/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.2938 - acc: 0.8454
# Epoch 86/100
# 537/537 [==============================] - 0s 11us/sample - loss: 0.2907 - acc: 0.8510
# Epoch 87/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.2870 - acc: 0.8492
# Epoch 88/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.2854 - acc: 0.8510
# Epoch 89/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.2851 - acc: 0.8529
# Epoch 90/100
# 537/537 [==============================] - 0s 22us/sample - loss: 0.2840 - acc: 0.8492
# Epoch 91/100
# 537/537 [==============================] - 0s 17us/sample - loss: 0.2820 - acc: 0.8510
# Epoch 92/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.2814 - acc: 0.8492
# Epoch 93/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.2800 - acc: 0.8492
# Epoch 94/100
# 537/537 [==============================] - 0s 13us/sample - loss: 0.2836 - acc: 0.8510
# Epoch 95/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.2816 - acc: 0.8492
# Epoch 96/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.2818 - acc: 0.8473
# Epoch 97/100
# 537/537 [==============================] - 0s 15us/sample - loss: 0.2761 - acc: 0.8492
# Epoch 98/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.2763 - acc: 0.8473
# Epoch 99/100
# 537/537 [==============================] - 0s 19us/sample - loss: 0.2778 - acc: 0.8547
# Epoch 100/100
# 537/537 [==============================] - 0s 20us/sample - loss: 0.2737 - acc: 0.8454

# %%
# over the training set
y_pred=model.predict_classes(X_Train)
print(confusion_matrix(Y_Train, y_pred))
print(classification_report(Y_Train, y_pred))
# Out:
# [[318  32]
#  [ 49 138]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89       350
#            1       0.81      0.74      0.77       187
#
#    micro avg       0.85      0.85      0.85       537
#    macro avg       0.84      0.82      0.83       537
# weighted avg       0.85      0.85      0.85       537

# %%
# over the test set
y_pred=model.predict_classes(X_Test)
print(confusion_matrix(Y_Test, y_pred))
print(classification_report(Y_Test, y_pred))
# Out:
# [[125  25]
#  [ 29  52]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       150
#            1       0.68      0.64      0.66        81
#
#    micro avg       0.77      0.77      0.77       231
#    macro avg       0.74      0.74      0.74       231
# weighted avg       0.76      0.77      0.76       231

# %%
tfjs.converters.save_keras_model(model, 'modelready')
